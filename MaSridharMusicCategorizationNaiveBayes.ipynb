# %% [markdown]
# <a href="https://colab.research.google.com/github/kylama/musicrecognition/blob/main/MaSridharMusicCategorizationNaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
# Importing data set
df = pd.read_csv('songs_normalize.csv')

# Making the loudness features positive values
df['loudness'] = df['loudness'].abs()

xDf = df[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
yDf = df['genre']

display(xDf)
display(yDf)
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.751   0.834    1     5.444       0.0437        0.3000
# 1            0.434   0.897    0     4.918       0.0488        0.0103
# 2            0.529   0.496    7     9.007       0.0290        0.1730
# 3            0.551   0.913    0     4.063       0.0466        0.0263
# 4            0.614   0.928    8     4.806       0.0516        0.0408
# ...            ...     ...  ...       ...          ...           ...
# 1995         0.842   0.734    1     5.065       0.0588        0.0427
# 1996         0.552   0.702    9     5.707       0.1570        0.1170
# 1997         0.847   0.678    9     8.635       0.1090        0.0669
# 1998         0.741   0.520    8     7.513       0.0656        0.4500
# 1999         0.695   0.762    0     3.497       0.0395        0.1920
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000018    0.3550    0.894   95.053
# ...

# %%
y_relationship = np.reshape(yDf, (len(yDf), ))
for i, value in enumerate(yDf):
  x = value.split(", ")
  value = x[0]
  y_relationship[i] = value
print(y_relationship[0:15])
# Out:
# ['pop' 'rock' 'pop' 'rock' 'pop' 'hip hop' 'hip hop' 'pop' 'pop'
#  'Dance/Electronic' 'pop' 'pop' 'pop' 'rock' 'pop']

# %%
# Split the data into train/test split
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size = 0.2)
print(X_train)
print(X_test)
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 1669         0.611   0.700    9     5.331       0.0436       0.01990
# 697          0.536   0.612    4     5.847       0.2720       0.11900
# 311          0.778   0.879    8     4.951       0.0371       0.39900
# 1454         0.885   0.581   11     8.813       0.0378       0.42700
# 1394         0.509   0.538    7     7.335       0.0572       0.38500
# ...            ...     ...  ...       ...          ...           ...
# 1680         0.647   0.932   11     3.515       0.0824       0.00383
# 1407         0.399   0.787    1     2.880       0.0499       0.01970
# 1531         0.746   0.877    9     3.782       0.0666       0.03750
# 489          0.668   0.905    6     5.395       0.0380       0.00232
# 258          0.567   0.580    4     5.757       0.2230       0.00840
#
#       instrumentalness  liveness  valence    tempo
# 1669          0.000000    0.0549    0.213  104.981
# ...

# %%
# Training the naive bayes model
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                    precision    recall  f1-score   support
#
#  Dance/Electronic       0.00      0.00      0.00         7
#     Folk/Acoustic       0.00      0.00      0.00         1
#               R&B       0.00      0.00      0.00         5
# World/Traditional       0.00      0.00      0.00         1
#           country       0.00      0.00      0.00         3
#           hip hop       0.55      0.45      0.50       154
#             latin       0.00      0.00      0.00         4
#             metal       0.00      0.00      0.00         1
#               pop       0.54      0.79      0.64       187
#              rock       0.00      0.00      0.00        34
#             set()       0.00      0.00      0.00         3
#
#          accuracy                           0.54       400
#         macro avg       0.10      0.11      0.10       400
#      weighted avg       0.46      0.54      0.49       400
# ...
