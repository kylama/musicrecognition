# %% [markdown]
# <a href="https://colab.research.google.com/github/kylama/musicrecognition/blob/main/MaSridharMusicCategorizationKNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs

# Import the k-Nearest Neighbors model from the sklearn library
from sklearn.neighbors import KNeighborsClassifier

# Import the train/test data split function from the sklearn library
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('songs_normalize.csv')

xDf = df[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
yDf = df['genre']
songDf = df['song']

display(xDf)
display(yDf)
display(songDf)
print(songDf[0])
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.751   0.834    1    -5.444       0.0437        0.3000
# 1            0.434   0.897    0    -4.918       0.0488        0.0103
# 2            0.529   0.496    7    -9.007       0.0290        0.1730
# 3            0.551   0.913    0    -4.063       0.0466        0.0263
# 4            0.614   0.928    8    -4.806       0.0516        0.0408
# ...            ...     ...  ...       ...          ...           ...
# 1995         0.842   0.734    1    -5.065       0.0588        0.0427
# 1996         0.552   0.702    9    -5.707       0.1570        0.1170
# 1997         0.847   0.678    9    -8.635       0.1090        0.0669
# 1998         0.741   0.520    8    -7.513       0.0656        0.4500
# 1999         0.695   0.762    0    -3.497       0.0395        0.1920
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000018    0.3550    0.894   95.053
# 1             0.000000    0.6120    0.684  148.726
# 2             0.000000    0.2510    0.278  136.859
# 3             0.000013    0.3470    0.544  119.992
# 4             0.001040    0.0845    0.879  172.656
# ...                ...       ...      ...      ...
# 1995          0.000000    0.1060    0.952  137.958
# 1996          0.000021    0.1050    0.564  169.994
# 1997          0.000000    0.2740    0.811   97.984
# 1998          0.000002    0.2220    0.347  102.998
# 1999          0.002440    0.0863    0.553  120.042
#
# [2000 rows x 10 columns]
# 0                    pop
# 1              rock, pop
# 2           pop, country
# 3            rock, metal
# 4                    pop
#               ...
# 1995                 pop
# 1996                 pop
# 1997    hip hop, country
# 1998                 pop
# 1999             hip hop
# Name: genre, Length: 2000, dtype: object
# 0                       Oops!...I Did It Again
# 1                         All The Small Things
# 2                                      Breathe
# 3                                 It's My Life
# 4                                  Bye Bye Bye
#                          ...
# 1995                                    Sucker
# 1996                              Cruel Summer
# 1997                                The Git Up
# 1998    Dancing With A Stranger (with Normani)
# 1999                                   Circles
# Name: song, Length: 2000, dtype: object
# Oops!...I Did It Again

# %%
y_relationship = np.reshape(yDf, (len(yDf), ))
for i, value in enumerate(yDf):
  x = value.split(", ")
  value = x[0]
  y_relationship[i] = value
print(y_relationship[0:15])
# Out:
# ['pop' 'rock' 'pop' 'rock' 'pop' 'hip hop' 'hip hop' 'pop' 'pop'
#  'Dance/Electronic' 'pop' 'pop' 'pop' 'rock' 'pop']

# %%
# Function for transforming genre data (y) into numerical data
for i, element in enumerate(y_relationship):
  if element == 'pop':
    yDf[i] = 1
  elif element == 'hip hop':
    yDf[i] = 2
  elif element == 'rock':
    yDf[i] = 3
  elif element == 'country':
    yDf[i] = 4
  elif element == 'metal':
    yDf[i] = 5
  elif element == 'R&B':
    yDf[i] = 6
  elif element == 'Dance/Electronics':
    yDf[i] = 7
  elif element == 'Folk/Acoustic':
    yDf[i] = 8
  elif element == 'latin':
    yDf[i] = 9
  elif element == 'blues':
    yDf[i] = 10
  else:
    yDf[i] = 0
print(yDf)
print(yDf.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 4
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 8
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 9
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 6
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 4
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 9
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# 0       1
# 1       3
# 2       1
# 3       3
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    2
# 1998    1
# 1999    2
# Name: genre, Length: 2000, dtype: object
# (2000,)
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 9
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 9
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 9
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 3
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 0
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2
# <ipython-input-231-0fd4168e0625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 1
# <ipython-input-231-0fd4168e0625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf[i] = 2

# %%
yDf
# Out:
# 0       1
# 1       3
# 2       1
# 3       3
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    2
# 1998    1
# 1999    2
# Name: genre, Length: 2000, dtype: object

# %%
copy = pd.DataFrame(yDf)
copy['genre'].unique()
# Out:
# array([1, 3, 2, 0, 5, 6, 8, 9, 4], dtype=object)

# %%
copy
# Out:
#      genre
# 0        1
# 1        3
# 2        1
# 3        3
# 4        1
# ...    ...
# 1995     1
# 1996     1
# 1997     2
# 1998     1
# 1999     2
#
# [2000 rows x 1 columns]

# %%
# def num_to_genre(data_frame):
#   for i in range(len(y_test)):
#     true = data_frame[i]
#     if true == 1:
#       true = 'pop'
#     elif true == 2:
#       true = 'hip hop'
#     elif true == 3:
#       true = 'rock'
#     elif true == 4:
#       true = 'country'
#     elif true == 5:
#       true = 'metal'
#     elif true == 6:
#       true = 'R&B'
#     elif true == 7:
#       true = 'Dance/Electronics'
#     elif true == 8:
#       true = 'Folk/Acoustic'
#     elif true == 9:
#       true = 'latin'
#     elif true == 10:
#       true = 'blues'
#     else:
#       true = 'none'

# %%
def KNN(k):
  accuracy = [] # declare an empty list to hold the accuracy
  for i in range(1): # for 10 times
    X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size = 0.2, random_state = i) # split the data into train/test split
    y_train = np.array(y_train.astype(int))
    y_test = np.array(y_test.astype(int))

    scaler = StandardScaler() # standardize the data
    scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model = KNeighborsClassifier(n_neighbors = k, weights = "distance") # train a KNN model using the training data and labels
    model.fit(X_train_scaled, y_train)
    print(X_train_scaled)
    print(y_relationship)

    y_hat = model.predict(X_test_scaled)

    score = model.score(X_test_scaled, y_test) # calculate the accuracy of the model using the testing data

    accuracy.append(score) # append the accuracy to the list containing all accuracies;

  print(accuracy)

  y_pred = model.predict(X_test)

  def num_to_genre(holder):
    if holder == 1:
      holder = 'pop'
    elif holder == 2:
      holder = 'hip hop'
    elif holder == 3:
      holder = 'rock'
    elif holder == 4:
      holder = 'country'
    elif holder == 5:
      holder = 'metal'
    elif holder == 6:
      holder = 'R&B'
    elif holder == 7:
      holder = 'Dance/Electronics'
    elif holder == 8:
      holder = 'Folk/Acoustic'
    elif holder == 9:
      holder = 'latin'
    elif holder == 10:
      holder = 'blues'
    else:
      holder = 'none'
    return holder

  for i in range(len(y_test)):
    true = y_test[i]
    pred = y_pred[i]
    print("True: ", num_to_genre(true))
    print("Pred: ", num_to_genre(pred))
    print("")

  avg_accuracy = sum(accuracy) / len(accuracy) # calculate the average accuracy by averaging all elements in the list holding all accuracies
  print("average accurcy of k =", k, ":", avg_accuracy)

# %%
KNN(25)
# Out:
# [[-1.36873076  0.93092666 -1.22940199 ... -0.49460835 -0.27534948
#   -1.04150617]
#  [ 0.96168177 -2.5052336   0.42473384 ... -0.72381416  1.34450304
#    1.72229586]
#  [-0.53438553  0.18050086  0.97611245 ...  0.83015917  0.64317025
#    2.24356642]
#  ...
#  [-0.32579922  0.08176062  0.97611245 ... -0.25629038 -0.82284153
#   -0.44961499]
#  [ 1.2206165  -0.83981493 -0.40233408 ... -0.6649356  -0.20295383
#   -1.11492771]
#  [-0.08844239 -0.64233445 -0.67802338 ...  0.67595343  0.82868408
#    0.15646753]]
# [1 3 1 ... 2 1 2]
# [0.64]
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  none
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:458: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  none
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  latin
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  none
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  rock
# Pred:  hip hop
#
# True:  country
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  none
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  none
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  latin
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  none
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  country
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  none
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  R&B
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  country
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  rock
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  country
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  metal
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  none
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  none
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  rock
# Pred:  pop
#
# True:  none
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  R&B
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  rock
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  rock
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  hip hop
#
# True:  R&B
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  hip hop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  latin
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  pop
# Pred:  pop
#
# True:  hip hop
# Pred:  pop
#
# average accurcy of k = 25 : 0.64
