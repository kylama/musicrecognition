# %% [markdown]
# <a href="https://colab.research.google.com/github/kylama/musicrecognition/blob/main/MaSridharMusicCategorizationKNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs

# Import the k-Nearest Neighbors model from the sklearn library
from sklearn.neighbors import KNeighborsClassifier

# Import the train/test data split function from the sklearn library
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('songs_normalize.csv')

xDf = df[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
yDf = df[['genre', 'song']]
#songDf = df['song']

display(xDf)
display(yDf)
# display(songDf)
# print(songDf[0])
# Out:
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 0            0.751   0.834    1    -5.444       0.0437        0.3000
# 1            0.434   0.897    0    -4.918       0.0488        0.0103
# 2            0.529   0.496    7    -9.007       0.0290        0.1730
# 3            0.551   0.913    0    -4.063       0.0466        0.0263
# 4            0.614   0.928    8    -4.806       0.0516        0.0408
# ...            ...     ...  ...       ...          ...           ...
# 1995         0.842   0.734    1    -5.065       0.0588        0.0427
# 1996         0.552   0.702    9    -5.707       0.1570        0.1170
# 1997         0.847   0.678    9    -8.635       0.1090        0.0669
# 1998         0.741   0.520    8    -7.513       0.0656        0.4500
# 1999         0.695   0.762    0    -3.497       0.0395        0.1920
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000018    0.3550    0.894   95.053
# 1             0.000000    0.6120    0.684  148.726
# 2             0.000000    0.2510    0.278  136.859
# 3             0.000013    0.3470    0.544  119.992
# 4             0.001040    0.0845    0.879  172.656
# ...                ...       ...      ...      ...
# 1995          0.000000    0.1060    0.952  137.958
# 1996          0.000021    0.1050    0.564  169.994
# 1997          0.000000    0.2740    0.811   97.984
# 1998          0.000002    0.2220    0.347  102.998
# 1999          0.002440    0.0863    0.553  120.042
#
# [2000 rows x 10 columns]
#                  genre                                    song
# 0                  pop                  Oops!...I Did It Again
# 1            rock, pop                    All The Small Things
# 2         pop, country                                 Breathe
# 3          rock, metal                            It's My Life
# 4                  pop                             Bye Bye Bye
# ...                ...                                     ...
# 1995               pop                                  Sucker
# 1996               pop                            Cruel Summer
# 1997  hip hop, country                              The Git Up
# 1998               pop  Dancing With A Stranger (with Normani)
# 1999           hip hop                                 Circles
#
# [2000 rows x 2 columns]

# %%
y_relationship = np.reshape(yDf['genre'], (len(yDf), ))
for i, value in enumerate(yDf['genre']):
  x = value.split(", ")
  value = x[0]
  y_relationship[i] = value
print(y_relationship[0:15])
# Out:
# ['pop' 'rock' 'pop' 'rock' 'pop' 'hip hop' 'hip hop' 'pop' 'pop'
#  'Dance/Electronic' 'pop' 'pop' 'pop' 'rock' 'pop']

# %%
# Function for transforming genre data (y) into numerical data

for i, element in enumerate(y_relationship):
  if element == 'pop':
    yDf['genre'][i] = 1
  elif element == 'hip hop':
    yDf['genre'][i] = 2
  elif element == 'rock':
    yDf['genre'][i] = 3
  elif element == 'country':
    yDf['genre'][i] = 4
  elif element == 'metal':
    yDf['genre'][i] = 5
  elif element == 'R&B':
    yDf['genre'][i] = 6
  elif element == 'Dance/Electronics':
    yDf['genre'][i] = 7
  elif element == 'Folk/Acoustic':
    yDf['genre'][i] = 8
  elif element == 'latin':
    yDf['genre'][i] = 9
  elif element == 'blues':
    yDf['genre'][i] = 10
  else:
    yDf['genre'][i] = 0
print(yDf)
print(yDf.shape)

# for col in range(0,1):
#   for row in range(0,1999):
#     if col == 0:
#       if y_relationship[row][col:] == 'pop':
#         yDf[row][col] = 1
#       elif y_relationship[row][col:] == 'hip hop':
#         yDf[row][col] = 2
#       elif y_relationship[row][col:] == 'rock':
#         yDf[row][col] = 3
#       elif y_relationship[row][col:] == 'country':
#         yDf[row][col] = 4
#       elif y_relationship[row][col:] == 'metal':
#         yDf[row][col] = 5
#       elif y_relationship[row][col:] == 'R&B':
#         yDf[row][col] = 6
#       elif y_relationship[row][col:] == 'Dance/Electronics':
#         yDf[row][col] = 7
#       elif y_relationship[row][col:] == 'Folk/Acoustic':
#         yDf[row][col] = 8
#       elif y_relationship[row][col:] == 'latin':
#         yDf[row][col] = 9
#       elif y_relationship[row][col:] == 'blues':
#         yDf[row][col] = 10
#       else:
#         print(y_relationship[row][col:])
#         yDf[row][col] = 0
# print(yDf)
# print(yDf.shape)
# Out:
# <ipython-input-119-414e257d60cf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 1
# <ipython-input-119-414e257d60cf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 3
# <ipython-input-119-414e257d60cf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 2
# <ipython-input-119-414e257d60cf>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 0
# <ipython-input-119-414e257d60cf>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 5
# <ipython-input-119-414e257d60cf>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 6
# <ipython-input-119-414e257d60cf>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 8
# <ipython-input-119-414e257d60cf>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 9
# <ipython-input-119-414e257d60cf>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yDf['genre'][i] = 4
#      genre                                    song
# 0        1                  Oops!...I Did It Again
# 1        3                    All The Small Things
# 2        1                                 Breathe
# 3        3                            It's My Life
# 4        1                             Bye Bye Bye
# ...    ...                                     ...
# 1995     1                                  Sucker
# 1996     1                            Cruel Summer
# 1997     2                              The Git Up
# 1998     1  Dancing With A Stranger (with Normani)
# 1999     2                                 Circles
#
# [2000 rows x 2 columns]
# (2000, 2)

# %%
yDf
# Out:
#      genre                                    song
# 0        1                  Oops!...I Did It Again
# 1        3                    All The Small Things
# 2        1                                 Breathe
# 3        3                            It's My Life
# 4        1                             Bye Bye Bye
# ...    ...                                     ...
# 1995     1                                  Sucker
# 1996     1                            Cruel Summer
# 1997     2                              The Git Up
# 1998     1  Dancing With A Stranger (with Normani)
# 1999     2                                 Circles
#
# [2000 rows x 2 columns]

# %%
copy = pd.DataFrame(yDf)
copy['genre'].unique()
# Out:
# array([1, 3, 2, 0, 5, 6, 8, 9, 4], dtype=object)

# %%
copy
# Out:
#      genre                                    song
# 0        1                  Oops!...I Did It Again
# 1        3                    All The Small Things
# 2        1                                 Breathe
# 3        3                            It's My Life
# 4        1                             Bye Bye Bye
# ...    ...                                     ...
# 1995     1                                  Sucker
# 1996     1                            Cruel Summer
# 1997     2                              The Git Up
# 1998     1  Dancing With A Stranger (with Normani)
# 1999     2                                 Circles
#
# [2000 rows x 2 columns]

# %%
def KNN(k):
  accuracy = [] # declare an empty list to hold the accuracy
  for i in range(1): # for 10 times
    X_train, X_test, y_train, y_test, song_train, song_test = train_test_split(xDf, yDf['genre'], yDf['song'], test_size = 0.2, random_state = i) # split the data into train/test split
    y_train = np.array(y_train.astype(int))
    y_test = np.array(y_test.astype(int))
    song_train = np.array(song_train.astype(str))
    song_test = np.array(song_test.astype(str))

    scaler = StandardScaler() # standardize the data
    scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model = KNeighborsClassifier(n_neighbors = k, weights = "distance") # train a KNN model using the training data and labels
    model.fit(X_train_scaled, y_train)
    print(X_train_scaled)
    print(y_relationship)

    y_hat = model.predict(X_test_scaled)

    score = model.score(X_test_scaled, y_test) # calculate the accuracy of the model using the testing data

    accuracy.append(score) # append the accuracy to the list containing all accuracies;

  print(accuracy)

  y_pred = model.predict(X_test)

  def num_to_genre(holder):
    if holder == 1:
      holder = 'pop'
    elif holder == 2:
      holder = 'hip hop'
    elif holder == 3:
      holder = 'rock'
    elif holder == 4:
      holder = 'country'
    elif holder == 5:
      holder = 'metal'
    elif holder == 6:
      holder = 'R&B'
    elif holder == 7:
      holder = 'Dance/Electronics'
    elif holder == 8:
      holder = 'Folk/Acoustic'
    elif holder == 9:
      holder = 'latin'
    elif holder == 10:
      holder = 'blues'
    else:
      holder = 'none'
    return holder

  for i in range(len(y_test)):
    true = y_test[i]
    pred = y_pred[i]
    #print(song_test[i])
    song = song_test[i]
    print("Song Title: ", song)
    print("True: ", num_to_genre(true))
    print("Pred: ", num_to_genre(pred))
    print("")

  avg_accuracy = sum(accuracy) / len(accuracy) # calculate the average accuracy by averaging all elements in the list holding all accuracies
  print("average accurcy of k =", k, ":", avg_accuracy)

# %%
KNN(25)
# Out:
# [[-1.36873076  0.93092666 -1.22940199 ... -0.49460835 -0.27534948
#   -1.04150617]
#  [ 0.96168177 -2.5052336   0.42473384 ... -0.72381416  1.34450304
#    1.72229586]
#  [-0.53438553  0.18050086  0.97611245 ...  0.83015917  0.64317025
#    2.24356642]
#  ...
#  [-0.32579922  0.08176062  0.97611245 ... -0.25629038 -0.82284153
#   -0.44961499]
#  [ 1.2206165  -0.83981493 -0.40233408 ... -0.6649356  -0.20295383
#   -1.11492771]
#  [-0.08844239 -0.64233445 -0.67802338 ...  0.67595343  0.82868408
#    0.15646753]]
# [1 3 1 ... 2 1 2]
# [0.64]
# Song Title:  Left Outside Alone
# True:  pop
# Pred:  pop
#
# Song Title:  Tongue Tied
# True:  pop
# Pred:  hip hop
#
# Song Title:  Louder (feat. Sian Evans) - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  Last Night
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Rake It Up (feat. Nicki Minaj)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  The Lazy Song
# True:  pop
# Pred:  pop
#
# Song Title:  Waiting For Love
# True:  pop
# Pred:  pop
#
# Song Title:  Wake Me Up
# True:  pop
# Pred:  hip hop
#
# Song Title:  Rise
# True:  pop
# Pred:  hip hop
#
# Song Title:  The Riddle
# True:  pop
# Pred:  hip hop
#
# Song Title:  Faded
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  King
# True:  pop
# Pred:  pop
#
# Song Title:  Gimme the Light
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Izzo (H.O.V.A.)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Cupid's Chokehold / Breakfast in America - Radio Mix
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Love Lies (with Normani)
# True:  pop
# Pred:  pop
#
# Song Title:  Turn Me On
# True:  hip hop
# Pred:  pop
#
# Song Title:  Leave Me Alone
# True:  hip hop
# Pred:  pop
#
# Song Title:  Confident
# True:  pop
# Pred:  hip hop
#
# Song Title:  In The Dark
# True:  pop
# Pred:  pop
#
# Song Title:  Lost in the Fire (feat. The Weeknd)
# True:  none
# Pred:  hip hop
#
# Song Title:  One Day / Reckoning Song (Wankelmut Remix) [Radio Edit]
# True:  pop
# Pred:  hip hop
#
# Song Title:  Runaway Love
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  One Last Time
# True:  pop
# Pred:  pop
#
# Song Title:  Empire State of Mind (Part II) Broken Down
# True:  pop
# Pred:  hip hop
#
# Song Title:  The Other Side
# True:  hip hop
# Pred:  pop
#
# Song Title:  My Happy Ending
# True:  pop
# Pred:  pop
#
# Song Title:  We R Who We R
# True:  pop
# Pred:  pop
#
# Song Title:  Just A Lil Bit
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Old Town Road
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Domino
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Hey Baby (Drop It to the Floor) (feat. T-Pain)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Money In The Grave (Drake ft. Rick Ross)
# True:  hip hop
# Pred:  pop
#
# Song Title:  DNA.
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  How Low
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Black Betty - Edit
# True:  rock
# Pred:  hip hop
#
# Song Title:  Beautiful Monster
# True:  pop
# Pred:  hip hop
#
# Song Title:  If You Come Back
# True:  pop
# Pred:  pop
#
# Song Title:  Slow Motion
# True:  hip hop
# Pred:  pop
#
# Song Title:  I Love College
# True:  hip hop
# Pred:  pop
#
# Song Title:  What'chu Like (feat. Tyrese)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Why'd You Only Call Me When You're High?
# True:  rock
# Pred:  hip hop
#
# Song Title:  Impossible
# True:  pop
# Pred:  pop
#
# Song Title:  Better Off Alone
# True:  pop
# Pred:  pop
#
# Song Title:  Don't Let Me Down
# True:  pop
# Pred:  pop
#
# Song Title:  How We Do
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Say Yes
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  She Hates Me
# True:  rock
# Pred:  hip hop
#
# Song Title:  Middle Of The Night
# True:  pop
# Pred:  pop
#
# Song Title:  Midnight City
# True:  rock
# Pred:  pop
#
# Song Title:  Watch Me (Whip / Nae Nae)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Beauty And A Beat
# True:  pop
# Pred:  hip hop
#
# Song Title:  That's the Way It Is
# True:  pop
# Pred:  pop
#
# Song Title:  I Predict A Riot
# True:  rock
# Pred:  pop
#
# Song Title:  Oh Boy
# True:  hip hop
# Pred:  pop
#
# Song Title:  Russian Roulette
# True:  hip hop
# Pred:  pop
#
# Song Title:  Diary (feat. Tony! Toni! Tone! & Jermaine Paul)
# True:  pop
# Pred:  pop
#
# Song Title:  Call on Me - Ryan Riback Remix
# True:  pop
# Pred:  hip hop
#
# Song Title:  Alejandro
# True:  pop
# Pred:  pop
#
# Song Title:  Never Forget You
# True:  pop
# Pred:  pop
#
# Song Title:  Another Way to Die
# True:  rock
# Pred:  pop
#
# Song Title:  Wish You Were Mine - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  On The Floor
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Thinking About You (feat. Ayah Marar)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Case Of The Ex (Whatcha Gonna Do)
# True:  pop
# Pred:  hip hop
#
# Song Title:  Sweetest Girl (Dollar Bill) (feat. Akon, Lil' Wayne & Niia)
# True:  none
# Pred:  hip hop
#
# Song Title:  Sweet Dreams
# True:  pop
# Pred:  hip hop
#
# Song Title:  Hot Right Now (feat. RITA ORA) - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  Boulevard of Broken Dreams
# True:  rock
# Pred:  pop
#
# Song Title:  21 Questions
# True:  hip hop
# Pred:  pop
#
# Song Title:  Sk8er Boi
# True:  pop
# Pred:  pop
#
# Song Title:  Viva La Vida
# True:  rock
# Pred:  hip hop
#
# Song Title:  Plug Walk
# True:  hip hop
# Pred:  pop
#
# Song Title:  Too Good At Goodbyes
# True:  pop
# Pred:  hip hop
#
# Song Title:  Magic Stick
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  This One's for You (feat. Zara Larsson) (Official Song UEFA EURO 2016)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Youth of the Nation
# True:  rock
# Pred:  pop
#
# Song Title:  Love
# True:  pop
# Pred:  hip hop
#
# Song Title:  There's Nothing Holdin' Me Back
# True:  pop
# Pred:  pop
#
# Song Title:  Thinking out Loud
# True:  pop
# Pred:  hip hop
#
# Song Title:  Bad Romance
# True:  pop
# Pred:  hip hop
#
# Song Title:  The Middle
# True:  rock
# Pred:  pop
#
# Song Title:  Unwell
# True:  pop
# Pred:  pop
#
# Song Title:  Down With The Trumpets
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Pink + White
# True:  hip hop
# Pred:  pop
#
# Song Title:  Caught in the Middle
# True:  pop
# Pred:  hip hop
#
# Song Title:  Swalla (feat. Nicki Minaj & Ty Dolla $ign)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Like I Love You
# True:  pop
# Pred:  hip hop
#
# Song Title:  My Boo
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Crazy In Love (feat. Jay-Z)
# True:  pop
# Pred:  hip hop
#
# Song Title:  Incomplete
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Te Amo
# True:  hip hop
# Pred:  pop
#
# Song Title:  Peaches & Cream
# True:  hip hop
# Pred:  pop
#
# Song Title:  Jubel - Radio Edit
# True:  pop
# Pred:  hip hop
#
# Song Title:  Sunset Lover
# True:  none
# Pred:  hip hop
#
# Song Title:  Circles
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Ransom
# True:  hip hop
# Pred:  pop
#
# Song Title:  Hemorrhage (In My Hands)
# True:  rock
# Pred:  pop
#
# Song Title:  Corazón (feat. Nego do Borel)
# True:  latin
# Pred:  pop
#
# Song Title:  Happy
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Hot Girl Summer (feat. Nicki Minaj & Ty Dolla $ign)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  What Makes You Beautiful
# True:  pop
# Pred:  pop
#
# Song Title:  Signs
# True:  hip hop
# Pred:  pop
#
# Song Title:  Way down We Go
# True:  rock
# Pred:  pop
#
# Song Title:  Big Pimpin'
# True:  hip hop
# Pred:  pop
#
# Song Title:  Chasing Pavements
# True:  pop
# Pred:  hip hop
#
# Song Title:  Sexy And I Know It
# True:  hip hop
# Pred:  pop
#
# Song Title:  Hurts So Good
# True:  rock
# Pred:  pop
#
# Song Title:  Good Time
# True:  rock
# Pred:  pop
#
# Song Title:  Hallelujah
# True:  pop
# Pred:  pop
#
# Song Title:  Holidae In
# True:  hip hop
# Pred:  pop
#
# Song Title:  Walk It Talk It
# True:  hip hop
# Pred:  pop
#
# Song Title:  Single Ladies (Put a Ring on It)
# True:  pop
# Pred:  pop
#
# Song Title:  Higher
# True:  pop
# Pred:  pop
#
# Song Title:  Antidote
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Unfaithful
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Mad Love
# True:  pop
# Pred:  pop
#
# Song Title:  Kryptonite
# True:  pop
# Pred:  pop
#
# Song Title:  You Give Me Something
# True:  pop
# Pred:  pop
#
# Song Title:  Lady - Hear Me Tonight
# True:  none
# Pred:  hip hop
#
# Song Title:  Kids
# True:  rock
# Pred:  pop
#
# Song Title:  The Real Slim Shady
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  What You Know
# True:  none
# Pred:  pop
#
# Song Title:  Fill Me In
# True:  hip hop
# Pred:  pop
#
# Song Title:  Starboy
# True:  pop
# Pred:  pop
#
# Song Title:  Blow
# True:  pop
# Pred:  pop
#
# Song Title:  Fire Burning
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Power Trip (feat. Miguel)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Ruby
# True:  rock
# Pred:  hip hop
#
# Song Title:  Dirt Road Anthem
# True:  country
# Pred:  hip hop
#
# Song Title:  Pjanoo - Radio Edit
# True:  pop
# Pred:  hip hop
#
# Song Title:  Love Don't Cost a Thing
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Uh Huh
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  In the End
# True:  rock
# Pred:  hip hop
#
# Song Title:  IDGAF
# True:  pop
# Pred:  pop
#
# Song Title:  Jesus Walks
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Already Gone
# True:  pop
# Pred:  pop
#
# Song Title:  Payphone
# True:  pop
# Pred:  hip hop
#
# Song Title:  LoveStoned / I Think She Knows (Interlude)
# True:  pop
# Pred:  hip hop
#
# Song Title:  Love at First Sight
# True:  pop
# Pred:  hip hop
#
# Song Title:  This Is What You Came For (feat. Rihanna)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Candyman
# True:  pop
# Pred:  pop
#
# Song Title:  Love Runs Out
# True:  pop
# Pred:  pop
#
# Song Title:  Don't Lie
# True:  hip hop
# Pred:  pop
#
# Song Title:  Independent Women, Pt. 1
# True:  pop
# Pred:  pop
#
# Song Title:  Grillz
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  X Gon' Give It To Ya
# True:  hip hop
# Pred:  pop
#
# Song Title:  Rapture (feat.Nadia Ali)
# True:  none
# Pred:  pop
#
# Song Title:  Scars To Your Beautiful
# True:  pop
# Pred:  pop
#
# Song Title:  Anywhere
# True:  hip hop
# Pred:  pop
#
# Song Title:  Dip It Low
# True:  hip hop
# Pred:  pop
#
# Song Title:  Old Town Road - Remix
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Galvanize
# True:  none
# Pred:  pop
#
# Song Title:  Alarm
# True:  pop
# Pred:  pop
#
# Song Title:  Party Up
# True:  hip hop
# Pred:  pop
#
# Song Title:  Smack That
# True:  pop
# Pred:  hip hop
#
# Song Title:  Unchained Melody
# True:  pop
# Pred:  pop
#
# Song Title:  I Gotta Feeling
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  True
# True:  pop
# Pred:  hip hop
#
# Song Title:  Can't Hold Us (feat. Ray Dalton)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Never Be the Same
# True:  pop
# Pred:  pop
#
# Song Title:  Mo Bamba
# True:  hip hop
# Pred:  pop
#
# Song Title:  E.T.
# True:  pop
# Pred:  pop
#
# Song Title:  Black Skinhead
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Clout (feat. Cardi B)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Hotel Room Service
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  2 Phones
# True:  hip hop
# Pred:  pop
#
# Song Title:  Flames
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Rule The World - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  Hey Daddy (Daddy's Home)
# True:  hip hop
# Pred:  pop
#
# Song Title:  My Humps
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Lovers on the Sun (feat. Sam Martin)
# True:  hip hop
# Pred:  pop
#
# Song Title:  You Rock My World
# True:  pop
# Pred:  hip hop
#
# Song Title:  Rise
# True:  pop
# Pred:  pop
#
# Song Title:  Remember the Name (feat. Styles of Beyond)
# True:  hip hop
# Pred:  pop
#
# Song Title:  China
# True:  latin
# Pred:  pop
#
# Song Title:  Black Horse And The Cherry Tree
# True:  none
# Pred:  hip hop
#
# Song Title:  Shake Ya Tailfeather (feat. P. Diddy & Murphy Lee) - 2016 Remaster
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Weak
# True:  rock
# Pred:  pop
#
# Song Title:  Dilemma
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Bad Blood
# True:  pop
# Pred:  pop
#
# Song Title:  The Hills
# True:  pop
# Pred:  hip hop
#
# Song Title:  Giant (with Rag'n'Bone Man)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Move Bitch
# True:  hip hop
# Pred:  pop
#
# Song Title:  Low Life (feat. The Weeknd)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Do I Wanna Know?
# True:  rock
# Pred:  hip hop
#
# Song Title:  Give Your Heart a Break
# True:  pop
# Pred:  pop
#
# Song Title:  In Love With a Girl
# True:  pop
# Pred:  pop
#
# Song Title:  Pass The Courvoisier Part II (feat. P. Diddy & Pharrell) - Remix
# True:  hip hop
# Pred:  pop
#
# Song Title:  I Like Me Better
# True:  pop
# Pred:  pop
#
# Song Title:  Prayer in C - Robin Schulz Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  The Rose
# True:  pop
# Pred:  pop
#
# Song Title:  Milkshake
# True:  pop
# Pred:  hip hop
#
# Song Title:  Shiver
# True:  pop
# Pred:  hip hop
#
# Song Title:  Can't Believe It (feat. Lil' Wayne)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Started From the Bottom
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Post Malone (feat. RANI)
# True:  pop
# Pred:  pop
#
# Song Title:  White Flag
# True:  pop
# Pred:  pop
#
# Song Title:  What's My Name?
# True:  hip hop
# Pred:  pop
#
# Song Title:  Hello
# True:  pop
# Pred:  pop
#
# Song Title:  Stereo Love - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  A Moment Like This
# True:  pop
# Pred:  pop
#
# Song Title:  Radio
# True:  pop
# Pred:  hip hop
#
# Song Title:  She Wolf
# True:  pop
# Pred:  pop
#
# Song Title:  I Could Be The One (Avicii Vs. Nicky Romero) - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  Passionfruit
# True:  hip hop
# Pred:  pop
#
# Song Title:  Hymn for the Weekend
# True:  rock
# Pred:  hip hop
#
# Song Title:  No Money
# True:  pop
# Pred:  pop
#
# Song Title:  One Call Away
# True:  hip hop
# Pred:  pop
#
# Song Title:  Bad (feat. Rihanna) - Remix
# True:  hip hop
# Pred:  pop
#
# Song Title:  If You're Not The One
# True:  pop
# Pred:  pop
#
# Song Title:  Teenagers
# True:  rock
# Pred:  pop
#
# Song Title:  I Know What You Want (feat. Flipmode Squad)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Just A Kiss
# True:  pop
# Pred:  pop
#
# Song Title:  Tainted Love
# True:  rock
# Pred:  pop
#
# Song Title:  Work It
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Rude
# True:  none
# Pred:  pop
#
# Song Title:  Murder On The Dancefloor
# True:  pop
# Pred:  hip hop
#
# Song Title:  Demons
# True:  rock
# Pred:  pop
#
# Song Title:  What's Left Of Me
# True:  pop
# Pred:  pop
#
# Song Title:  Toxic
# True:  pop
# Pred:  pop
#
# Song Title:  What Goes Around.../...Comes Around (Interlude)
# True:  pop
# Pred:  pop
#
# Song Title:  Lollipop
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Don't Phunk With My Heart
# True:  hip hop
# Pred:  pop
#
# Song Title:  Nine Million Bicycles
# True:  pop
# Pred:  hip hop
#
# Song Title:  Pop Style
# True:  hip hop
# Pred:  pop
#
# Song Title:  Take Me Back to London (feat. Stormzy)
# True:  pop
# Pred:  pop
#
# Song Title:  Homemade Dynamite - REMIX
# True:  pop
# Pred:  hip hop
#
# Song Title:  Everytime
# True:  pop
# Pred:  pop
#
# Song Title:  King's Dead (with Kendrick Lamar, Future & James Blake)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Dance, Dance
# True:  rock
# Pred:  pop
#
# Song Title:  Born to Make You Happy
# True:  pop
# Pred:  pop
#
# Song Title:  I Like It
# True:  hip hop
# Pred:  pop
#
# Song Title:  Cross Me (feat. Chance the Rapper & PnB Rock)
# True:  pop
# Pred:  hip hop
#
# Song Title:  Save That Shit
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Glad You Came
# True:  pop
# Pred:  pop
#
# Song Title:  Stereo Love - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  oui
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Nasty Girl (feat. Diddy, Nelly, Jagged Edge & Avery Storm) - 2005 Remaster
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Need U (100%) [feat. A*M*E] - Radio Edit
# True:  pop
# Pred:  hip hop
#
# Song Title:  Axel F
# True:  pop
# Pred:  pop
#
# Song Title:  As Good As I Once Was
# True:  country
# Pred:  hip hop
#
# Song Title:  You Found Me
# True:  pop
# Pred:  pop
#
# Song Title:  Naturally
# True:  pop
# Pred:  pop
#
# Song Title:  Come to Me (feat. Nicole Scherzinger)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Want U Back
# True:  pop
# Pred:  pop
#
# Song Title:  She Wants To Move
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  The Seed (2.0)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Green Light (feat. André 3000)
# True:  pop
# Pred:  pop
#
# Song Title:  Point Of View - Radio Edit
# True:  none
# Pred:  hip hop
#
# Song Title:  Options
# True:  none
# Pred:  hip hop
#
# Song Title:  Cold (feat. Future)
# True:  pop
# Pred:  pop
#
# Song Title:  Mama
# True:  pop
# Pred:  pop
#
# Song Title:  Final Song
# True:  pop
# Pred:  hip hop
#
# Song Title:  Human
# True:  R&B
# Pred:  pop
#
# Song Title:  Most Girls
# True:  pop
# Pred:  hip hop
#
# Song Title:  Stir Fry
# True:  hip hop
# Pred:  pop
#
# Song Title:  Let Me Love You
# True:  hip hop
# Pred:  pop
#
# Song Title:  Somebody That I Used To Know
# True:  none
# Pred:  hip hop
#
# Song Title:  Full Moon
# True:  hip hop
# Pred:  pop
#
# Song Title:  Back To December
# True:  pop
# Pred:  pop
#
# Song Title:  Never Be The Same Again
# True:  pop
# Pred:  pop
#
# Song Title:  It's Like That
# True:  pop
# Pred:  pop
#
# Song Title:  We Found Love
# True:  hip hop
# Pred:  pop
#
# Song Title:  Let Me Love You
# True:  pop
# Pred:  hip hop
#
# Song Title:  She Doesn't Mind
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Oblivion
# True:  pop
# Pred:  hip hop
#
# Song Title:  Vossi Bop
# True:  hip hop
# Pred:  pop
#
# Song Title:  Sucker for Pain (with Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign feat. X Ambassadors)
# True:  hip hop
# Pred:  pop
#
# Song Title:  It's A Vibe
# True:  hip hop
# Pred:  pop
#
# Song Title:  One Wish
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  About You Now
# True:  pop
# Pred:  hip hop
#
# Song Title:  The Boy Does Nothing
# True:  pop
# Pred:  pop
#
# Song Title:  Rock This Party - Everybody Dance Now
# True:  pop
# Pred:  pop
#
# Song Title:  Slow Down - 12" Version
# True:  hip hop
# Pred:  pop
#
# Song Title:  Memories (feat. Kid Cudi)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Acceptable in the 80's
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Overprotected - Radio Edit
# True:  pop
# Pred:  hip hop
#
# Song Title:  LUV
# True:  hip hop
# Pred:  pop
#
# Song Title:  Cooler Than Me - Single Mix
# True:  hip hop
# Pred:  pop
#
# Song Title:  I See Fire - From "The Hobbit - The Desolation Of Smaug"
# True:  pop
# Pred:  pop
#
# Song Title:  If I Die Young
# True:  country
# Pred:  hip hop
#
# Song Title:  Outside (feat. Ellie Goulding)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Music (feat. Marvin Gaye)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Alors on danse - Radio Edit
# True:  pop
# Pred:  hip hop
#
# Song Title:  America
# True:  rock
# Pred:  hip hop
#
# Song Title:  The Pretender
# True:  rock
# Pred:  pop
#
# Song Title:  Where'd You Go (feat. Holly Brook & Jonah Matranga)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Roar
# True:  pop
# Pred:  pop
#
# Song Title:  Thank God I Found You (feat. Joe & 98°)
# True:  pop
# Pred:  pop
#
# Song Title:  Clint Eastwood
# True:  hip hop
# Pred:  pop
#
# Song Title:  My House
# True:  hip hop
# Pred:  pop
#
# Song Title:  Titanium (feat. Sia)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Complicated
# True:  pop
# Pred:  hip hop
#
# Song Title:  Bonkers
# True:  hip hop
# Pred:  pop
#
# Song Title:  Scars
# True:  rock
# Pred:  pop
#
# Song Title:  Big Green Tractor
# True:  country
# Pred:  pop
#
# Song Title:  Crank That (Soulja Boy)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Somebody
# True:  none
# Pred:  hip hop
#
# Song Title:  I Kissed A Girl
# True:  pop
# Pred:  pop
#
# Song Title:  Up (feat. Demi Lovato)
# True:  pop
# Pred:  pop
#
# Song Title:  Whataya Want from Me
# True:  pop
# Pred:  pop
#
# Song Title:  Lights - Single Version
# True:  pop
# Pred:  pop
#
# Song Title:  Lips Of An Angel
# True:  pop
# Pred:  hip hop
#
# Song Title:  We Found Love
# True:  hip hop
# Pred:  pop
#
# Song Title:  bad guy
# True:  pop
# Pred:  pop
#
# Song Title:  Meant to Live
# True:  rock
# Pred:  pop
#
# Song Title:  Rock The Boat
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Rockabye (feat. Sean Paul & Anne-Marie)
# True:  pop
# Pred:  pop
#
# Song Title:  Mask Off
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Separated
# True:  pop
# Pred:  hip hop
#
# Song Title:  This Ain't a Love Song
# True:  pop
# Pred:  pop
#
# Song Title:  Otherside
# True:  rock
# Pred:  pop
#
# Song Title:  Eenie Meenie
# True:  hip hop
# Pred:  pop
#
# Song Title:  HandClap
# True:  pop
# Pred:  pop
#
# Song Title:  Everybody in Love
# True:  pop
# Pred:  pop
#
# Song Title:  Underneath It All
# True:  rock
# Pred:  pop
#
# Song Title:  Leave Right Now
# True:  pop
# Pred:  pop
#
# Song Title:  She Looks So Perfect
# True:  pop
# Pred:  pop
#
# Song Title:  Sorry
# True:  pop
# Pred:  hip hop
#
# Song Title:  Call Me When You're Sober
# True:  metal
# Pred:  pop
#
# Song Title:  Rather Be (feat. Jess Glynne)
# True:  pop
# Pred:  pop
#
# Song Title:  Thong Song
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Can't Fight The Moonlight
# True:  pop
# Pred:  pop
#
# Song Title:  T-Shirt
# True:  hip hop
# Pred:  pop
#
# Song Title:  Worth It (feat. Kid Ink)
# True:  pop
# Pred:  pop
#
# Song Title:  Clumsy
# True:  pop
# Pred:  pop
#
# Song Title:  Team
# True:  pop
# Pred:  pop
#
# Song Title:  Look Right Through - MK Vocal Edit
# True:  none
# Pred:  hip hop
#
# Song Title:  With Arms Wide Open
# True:  pop
# Pred:  hip hop
#
# Song Title:  Swimming Pools (Drank) - Extended Version
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Attention
# True:  pop
# Pred:  hip hop
#
# Song Title:  Treat You Better
# True:  pop
# Pred:  pop
#
# Song Title:  Misery
# True:  pop
# Pred:  hip hop
#
# Song Title:  Live Your Life
# True:  hip hop
# Pred:  pop
#
# Song Title:  I'm Not a Girl, Not Yet a Woman
# True:  pop
# Pred:  hip hop
#
# Song Title:  Wait for You
# True:  none
# Pred:  hip hop
#
# Song Title:  Thank You
# True:  pop
# Pred:  hip hop
#
# Song Title:  Heroes (we could be)
# True:  pop
# Pred:  pop
#
# Song Title:  No More Drama
# True:  pop
# Pred:  pop
#
# Song Title:  Without Me
# True:  pop
# Pred:  hip hop
#
# Song Title:  Still into You
# True:  pop
# Pred:  pop
#
# Song Title:  Rockstar
# True:  rock
# Pred:  pop
#
# Song Title:  Loca People - Radio Edit
# True:  none
# Pred:  pop
#
# Song Title:  The Great Escape
# True:  pop
# Pred:  pop
#
# Song Title:  My Type
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  You Don't Know Me - Radio Edit
# True:  hip hop
# Pred:  pop
#
# Song Title:  The Next Episode
# True:  hip hop
# Pred:  pop
#
# Song Title:  See You Again (feat. Charlie Puth)
# True:  hip hop
# Pred:  pop
#
# Song Title:  One Step At a Time
# True:  pop
# Pred:  hip hop
#
# Song Title:  I Just Wanna Love U (Give It 2 Me)
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Freaky Friday (feat. Chris Brown)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Shower
# True:  pop
# Pred:  hip hop
#
# Song Title:  When You're Gone
# True:  pop
# Pred:  pop
#
# Song Title:  Crack A Bottle
# True:  hip hop
# Pred:  pop
#
# Song Title:  Tonight Tonight
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Latch
# True:  pop
# Pred:  hip hop
#
# Song Title:  lovely (with Khalid)
# True:  pop
# Pred:  hip hop
#
# Song Title:  All The Small Things
# True:  rock
# Pred:  pop
#
# Song Title:  Back To Black
# True:  R&B
# Pred:  pop
#
# Song Title:  I Got U
# True:  pop
# Pred:  pop
#
# Song Title:  One Minute Man (feat. Ludacris)
# True:  hip hop
# Pred:  pop
#
# Song Title:  Gangnam Style (강남스타일)
# True:  pop
# Pred:  pop
#
# Song Title:  Down
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Salt Shaker
# True:  hip hop
# Pred:  pop
#
# Song Title:  Ugly Heart
# True:  pop
# Pred:  pop
#
# Song Title:  Crash and Burn
# True:  pop
# Pred:  hip hop
#
# Song Title:  Like a Stone
# True:  rock
# Pred:  pop
#
# Song Title:  Chasing The Sun
# True:  pop
# Pred:  pop
#
# Song Title:  Burn
# True:  pop
# Pred:  hip hop
#
# Song Title:  Me Against the Music (feat. Madonna) - LP Version / Video Mix
# True:  pop
# Pred:  hip hop
#
# Song Title:  Disturbia
# True:  hip hop
# Pred:  pop
#
# Song Title:  Get Low
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Proper Education - Radio Edit
# True:  pop
# Pred:  pop
#
# Song Title:  Sail
# True:  pop
# Pred:  hip hop
#
# Song Title:  Jumpman
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Take Me Out
# True:  rock
# Pred:  hip hop
#
# Song Title:  Trick Me
# True:  pop
# Pred:  hip hop
#
# Song Title:  Moves Like Jagger - Studio Recording From "The Voice" Performance
# True:  pop
# Pred:  pop
#
# Song Title:  Irresistible
# True:  pop
# Pred:  pop
#
# Song Title:  Good Life
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Too Lost In You
# True:  pop
# Pred:  hip hop
#
# Song Title:  Shackles (Praise You)
# True:  R&B
# Pred:  pop
#
# Song Title:  How To Love
# True:  hip hop
# Pred:  pop
#
# Song Title:  Wearing My Rolex - Radio Edit
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  Best Song Ever
# True:  pop
# Pred:  pop
#
# Song Title:  As Long As You Love Me
# True:  pop
# Pred:  pop
#
# Song Title:  Pon de Replay
# True:  hip hop
# Pred:  pop
#
# Song Title:  Dear Darlin'
# True:  pop
# Pred:  pop
#
# Song Title:  Jocelyn Flores
# True:  hip hop
# Pred:  hip hop
#
# Song Title:  The Whole World (feat. Killer Mike)
# True:  hip hop
# Pred:  pop
#
# Song Title:  He Can't Love U
# True:  hip hop
# Pred:  pop
#
# Song Title:  Vaina Loca
# True:  latin
# Pred:  pop
#
# Song Title:  I Love It (feat. Charli XCX)
# True:  pop
# Pred:  pop
#
# Song Title:  Berzerk
# True:  hip hop
# Pred:  pop
#
# Song Title:  Laffy Taffy
# True:  hip hop
# Pred:  pop
#
# Song Title:  Beautiful
# True:  hip hop
# Pred:  pop
#
# Song Title:  no tears left to cry
# True:  pop
# Pred:  pop
#
# Song Title:  Ciao Adios
# True:  pop
# Pred:  pop
#
# Song Title:  Don't Love You No More (I'm Sorry)
# True:  hip hop
# Pred:  pop
#
# average accurcy of k = 25 : 0.64
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:458: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
